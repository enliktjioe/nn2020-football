# %% [markdown]
# ## Dataset Preparation
# Download __database.sqlite__ from [here](https://www.kaggle.com/hugomathien/soccer)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlite3
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

path = "datasets/"  #Insert path here
database = path + 'database.sqlite'

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output\

# %%
conn = sqlite3.connect(database)

tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
type(tables)
# Out:
# pandas.core.frame.DataFrame

# %%
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %%
team_t = pd.read_sql("""SELECT * FROM Team""", conn)

# %%
team_t
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
match_t = pd.read_sql("""SELECT * FROM Match""", conn)
match_t
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0            492473              9987              9993               1  ...
# 1            492474             10000              9994               0  ...
# 2            492475              9984              8635               0  ...
# 3            492476              9991              9998               5  ...
# 4            492477              7947              9985               1  ...
# ...             ...               ...               ...             ...  ...
# 25974       1992091             10190             10191               1  ...
# 25975       1992092              9824             10199               1  ...
# 25976       1992093              9956             10179               2  ...
# 25977       1992094              7896             10243               0  ...
# 25978       1992095             10192              9931               4  ...
#
#         SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0      4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1      3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2      2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3      7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4      1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25974   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25975   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25976   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25977   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25978   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [25979 rows x 115 columns]

# %%
m = team_t.set_index('team_api_id')['team_long_name'].to_dict()
h = match_t.filter(like='home_team_api_id')
match_t[h.columns] = h.replace(m)
a = match_t.filter(like='away_team_api_id')
match_t[a.columns] = a.replace(m)

# %%
match_t
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id         home_team_api_id   away_team_api_id  \
# 0            492473                 KRC Genk       Beerschot AC
# 1            492474         SV Zulte-Waregem   Sporting Lokeren
# 2            492475        KSV Cercle Brugge     RSC Anderlecht
# 3            492476                 KAA Gent          RAEC Mons
# 4            492477            FCV Dender EH  Standard de Liège
# ...             ...                      ...                ...
# 25974       1992091            FC St. Gallen            FC Thun
# 25975       1992092                 FC Vaduz          FC Luzern
# 25976       1992093  Grasshopper Club Zürich            FC Sion
# 25977       1992094                   Lugano          FC Zürich
# 25978       1992095           BSC Young Boys           FC Basel
#
#        home_team_goal  ...   SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH  \
# 0                   1  ...  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73
# 1                   0  ...  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91
# 2                   0  ...  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30
# 3                   5  ...  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44
# 4                   1  ...  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75
# ...               ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25974               1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25975               1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25976               2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25977               0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25978               4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         BSD   BSA
# 0      3.40  4.20
# 1      3.25  3.60
# 2      3.20  2.75
# 3      3.75  6.50
# 4      3.30  1.67
# ...     ...   ...
# 25974   NaN   NaN
# 25975   NaN   NaN
# 25976   NaN   NaN
# 25977   NaN   NaN
# 25978   NaN   NaN
#
# [25979 rows x 115 columns]

# %%
league_t = pd.read_sql("""SELECT * FROM League""", conn)
league_t
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
selected_leagues = pd.read_sql("""SELECT *
                        FROM League
                        WHERE id IN(1729, 21518);""", conn)
selected_leagues
# Out:
#       id  country_id                    name
# 0   1729        1729  England Premier League
# 1  21518       21518         Spain LIGA BBVA

# %%
matches = pd.read_sql("""SELECT *
                        FROM Match
                        WHERE league_id IN(1729, 21518);""", conn)
matches
# Out:
#          id  country_id  league_id     season  stage                 date  \
# 0      1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1      1730        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 2      1731        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 3      1732        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 4      1733        1729       1729  2008/2009      1  2008-08-17 00:00:00
# ...     ...         ...        ...        ...    ...                  ...
# 6075  24553       21518      21518  2015/2016      9  2015-10-25 00:00:00
# 6076  24554       21518      21518  2015/2016      9  2015-10-24 00:00:00
# 6077  24555       21518      21518  2015/2016      9  2015-10-26 00:00:00
# 6078  24556       21518      21518  2015/2016      9  2015-10-24 00:00:00
# 6079  24557       21518      21518  2015/2016      9  2015-10-23 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0           489042             10260             10261               1  ...
# 1           489043              9825              8659               1  ...
# 2           489044              8472              8650               0  ...
# 3           489045              8654              8528               2  ...
# 4           489046             10252              8456               4  ...
# ...            ...               ...               ...             ...  ...
# 6075       2030167              9906             10267               2  ...
# 6076       2030168              9864              9783               2  ...
# 6077       2030169              8315              9869               3  ...
# 6078       2030170              7878              8603               1  ...
# 6079       2030171              8370              8558               3  ...
#
#         SJA   VCH  VCD    VCA   GBH   GBD   GBA   BSH   BSD    BSA
# 0     10.00  1.28  5.5  12.00  1.30  4.75  10.0  1.29  4.50  11.00
# 1     12.00  1.25  6.0  13.00  1.22  5.50  13.0  1.22  5.00  13.00
# 2      1.73  5.50  3.8   1.65  5.00  3.40   1.7  4.50  3.40   1.73
# 3      3.75  1.90  3.5   4.35  1.91  3.25   4.0  1.91  3.25   3.80
# 4      3.75  1.90  3.5   4.35  1.91  3.25   4.0  1.91  3.30   3.75
# ...     ...   ...  ...    ...   ...   ...   ...   ...   ...    ...
# 6075    NaN  1.57  4.0   7.00   NaN   NaN   NaN   NaN   NaN    NaN
# 6076    NaN  2.30  3.4   3.40   NaN   NaN   NaN   NaN   NaN    NaN
# 6077    NaN  1.55  4.2   7.00   NaN   NaN   NaN   NaN   NaN    NaN
# 6078    NaN  2.30  3.4   3.30   NaN   NaN   NaN   NaN   NaN    NaN
# 6079    NaN  2.20  3.6   3.50   NaN   NaN   NaN   NaN   NaN    NaN
#
# [6080 rows x 115 columns]

# %%
h = matches.filter(like='home_team_api_id')
matches[h.columns] = h.replace(m)
a = matches.filter(like='away_team_api_id')
matches[a.columns] = a.replace(m)

# %%
matches
# Out:
#          id  country_id  league_id     season  stage                 date  \
# 0      1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1      1730        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 2      1731        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 3      1732        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 4      1733        1729       1729  2008/2009      1  2008-08-17 00:00:00
# ...     ...         ...        ...        ...    ...                  ...
# 6075  24553       21518      21518  2015/2016      9  2015-10-25 00:00:00
# 6076  24554       21518      21518  2015/2016      9  2015-10-24 00:00:00
# 6077  24555       21518      21518  2015/2016      9  2015-10-26 00:00:00
# 6078  24556       21518      21518  2015/2016      9  2015-10-24 00:00:00
# 6079  24557       21518      21518  2015/2016      9  2015-10-23 00:00:00
#
#       match_api_id         home_team_api_id           away_team_api_id  \
# 0           489042        Manchester United           Newcastle United
# 1           489043                  Arsenal       West Bromwich Albion
# 2           489044               Sunderland                  Liverpool
# 3           489045          West Ham United             Wigan Athletic
# 4           489046              Aston Villa            Manchester City
# ...            ...                      ...                        ...
# 6075       2030167          Atlético Madrid                Valencia CF
# 6076       2030168                Málaga CF  RC Deportivo de La Coruña
# 6077       2030169  Athletic Club de Bilbao     Real Sporting de Gijón
# 6078       2030170               Granada CF        Real Betis Balompié
# 6079       2030171           Rayo Vallecano               RCD Espanyol
#
#       home_team_goal  ...    SJA   VCH  VCD    VCA   GBH   GBD   GBA   BSH  \
# 0                  1  ...  10.00  1.28  5.5  12.00  1.30  4.75  10.0  1.29
# 1                  1  ...  12.00  1.25  6.0  13.00  1.22  5.50  13.0  1.22
# 2                  0  ...   1.73  5.50  3.8   1.65  5.00  3.40   1.7  4.50
# 3                  2  ...   3.75  1.90  3.5   4.35  1.91  3.25   4.0  1.91
# 4                  4  ...   3.75  1.90  3.5   4.35  1.91  3.25   4.0  1.91
# ...              ...  ...    ...   ...  ...    ...   ...   ...   ...   ...
# 6075               2  ...    NaN  1.57  4.0   7.00   NaN   NaN   NaN   NaN
# 6076               2  ...    NaN  2.30  3.4   3.40   NaN   NaN   NaN   NaN
# 6077               3  ...    NaN  1.55  4.2   7.00   NaN   NaN   NaN   NaN
# 6078               1  ...    NaN  2.30  3.4   3.30   NaN   NaN   NaN   NaN
# 6079               3  ...    NaN  2.20  3.6   3.50   NaN   NaN   NaN   NaN
#
#        BSD    BSA
# 0     4.50  11.00
# 1     5.00  13.00
# 2     3.40   1.73
# 3     3.25   3.80
# 4     3.30   3.75
# ...    ...    ...
# 6075   NaN    NaN
# 6076   NaN    NaN
# 6077   NaN    NaN
# 6078   NaN    NaN
# 6079   NaN    NaN
#
# [6080 rows x 115 columns]

# %%
list(matches.columns)
# Out:
# ['id',
#  'country_id',
#  'league_id',
#  'season',
#  'stage',
#  'date',
#  'match_api_id',
#  'home_team_api_id',
#  'away_team_api_id',
#  'home_team_goal',
#  'away_team_goal',
#  'home_player_X1',
#  'home_player_X2',
#  'home_player_X3',
#  'home_player_X4',
#  'home_player_X5',
#  'home_player_X6',
#  'home_player_X7',
#  'home_player_X8',
#  'home_player_X9',
#  'home_player_X10',
#  'home_player_X11',
#  'away_player_X1',
#  'away_player_X2',
#  'away_player_X3',
#  'away_player_X4',
#  'away_player_X5',
#  'away_player_X6',
#  'away_player_X7',
#  'away_player_X8',
#  'away_player_X9',
#  'away_player_X10',
#  'away_player_X11',
#  'home_player_Y1',
#  'home_player_Y2',
#  'home_player_Y3',
#  'home_player_Y4',
#  'home_player_Y5',
#  'home_player_Y6',
#  'home_player_Y7',
#  'home_player_Y8',
#  'home_player_Y9',
#  'home_player_Y10',
#  'home_player_Y11',
#  'away_player_Y1',
#  'away_player_Y2',
#  'away_player_Y3',
#  'away_player_Y4',
#  'away_player_Y5',
#  'away_player_Y6',
#  'away_player_Y7',
#  'away_player_Y8',
#  'away_player_Y9',
#  'away_player_Y10',
#  'away_player_Y11',
#  'home_player_1',
#  'home_player_2',
#  'home_player_3',
#  'home_player_4',
#  'home_player_5',
#  'home_player_6',
#  'home_player_7',
#  'home_player_8',
#  'home_player_9',
#  'home_player_10',
#  'home_player_11',
#  'away_player_1',
#  'away_player_2',
#  'away_player_3',
#  'away_player_4',
#  'away_player_5',
#  'away_player_6',
#  'away_player_7',
#  'away_player_8',
#  'away_player_9',
#  'away_player_10',
#  'away_player_11',
#  'goal',
#  'shoton',
#  'shotoff',
#  'foulcommit',
#  'card',
#  'cross',
#  'corner',
#  'possession',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'LBH',
#  'LBD',
#  'LBA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'SJH',
#  'SJD',
#  'SJA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'GBH',
#  'GBD',
#  'GBA',
#  'BSH',
#  'BSD',
#  'BSA']

# %%
df = matches[matches.columns.drop(list(matches.filter(regex='player|BW|IW|LB|PS|WH|SJ|VC|GB|BS')))]

# %%
list(df.columns)
# Out:
# ['id',
#  'country_id',
#  'league_id',
#  'season',
#  'stage',
#  'date',
#  'match_api_id',
#  'home_team_api_id',
#  'away_team_api_id',
#  'home_team_goal',
#  'away_team_goal',
#  'goal',
#  'shoton',
#  'shotoff',
#  'foulcommit',
#  'card',
#  'cross',
#  'corner',
#  'possession',
#  'B365H',
#  'B365D',
#  'B365A']

# %%
df_EPL = df[df['league_id'] == 1729]
len(df_EPL)
# Out:
# 3040

# %%
df_LaLiga = df[df['league_id'] == 21518]
len(df_LaLiga)
# Out:
# 3040

# %%
# count shotonm shotoff, foulcommut
for i in range(len(df_EPL['shoton'])):
    data = df_EPL['shoton'][i]
    root = ET.fromstring(data)
    count = len(root.getchildren())
    df_EPL.at[i,'shoton'] = count
for i in range(len(df_EPL['shotoff'])):
    data = df_EPL['shotoff'][i]
    root = ET.fromstring(data)
    count = len(root.getchildren())
    df_EPL.at[i,'shotoff'] = count
for i in range(len(df_EPL['foulcommit'])):
    data = df_EPL['foulcommit'][i]
    root = ET.fromstring(data)
    count = len(root.getchildren())
    df_EPL.at[i,'foulcommit'] = count

# %%
df_EPL
# Out:
#         id  country_id  league_id     season  stage                 date  \
# 0     1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1     1730        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 2     1731        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 3     1732        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 4     1733        1729       1729  2008/2009      1  2008-08-17 00:00:00
# ...    ...         ...        ...        ...    ...                  ...
# 3035  4764        1729       1729  2015/2016      9  2015-10-17 00:00:00
# 3036  4765        1729       1729  2015/2016      9  2015-10-19 00:00:00
# 3037  4766        1729       1729  2015/2016      9  2015-10-17 00:00:00
# 3038  4767        1729       1729  2015/2016      9  2015-10-17 00:00:00
# 3039  4768        1729       1729  2015/2016      9  2015-10-17 00:00:00
#
#       match_api_id      home_team_api_id      away_team_api_id  \
# 0           489042     Manchester United      Newcastle United
# 1           489043               Arsenal  West Bromwich Albion
# 2           489044            Sunderland             Liverpool
# 3           489045       West Ham United        Wigan Athletic
# 4           489046           Aston Villa       Manchester City
# ...            ...                   ...                   ...
# 3035       1988795           Southampton        Leicester City
# 3036       1988796          Swansea City            Stoke City
# 3037       1988797     Tottenham Hotspur             Liverpool
# 3038       1988798               Watford               Arsenal
# 3039       1988799  West Bromwich Albion            Sunderland
#
#       home_team_goal  ...  shoton shotoff foulcommit  \
# 0                  1  ...      12      19         27
# 1                  1  ...      14      16         20
# 2                  0  ...      15       8         25
# 3                  2  ...      12      22         27
# 4                  4  ...      14       9         24
# ...              ...  ...     ...     ...        ...
# 3035               2  ...      12      16         26
# 3036               0  ...       6      15         21
# 3037               0  ...      16       7         26
# 3038               0  ...      15       9         23
# 3039               1  ...       8       8         26
#
#                                                    card  \
# 0     <card><value><comment>y</comment><stats><ycard...
# 1                                              <card />
# 2     <card><value><comment>y</comment><stats><ycard...
# 3     <card><value><comment>y</comment><stats><ycard...
# 4     <card><value><comment>y</comment><stats><ycard...
# ...                                                 ...
# 3035  <card><value><comment>y</comment><stats><ycard...
# 3036  <card><value><comment>y</comment><stats><ycard...
# 3037  <card><value><comment>y</comment><stats><ycard...
# 3038  <card><value><comment>y</comment><stats><ycard...
# 3039  <card><value><comment>y</comment><stats><ycard...
#
#                                                   cross  \
# 0     <cross><value><stats><crosses>1</crosses></sta...
# 1     <cross><value><stats><crosses>1</crosses></sta...
# 2     <cross><value><stats><crosses>1</crosses></sta...
# 3     <cross><value><stats><crosses>1</crosses></sta...
# 4     <cross><value><stats><corners>1</corners></sta...
# ...                                                 ...
# 3035  <cross><value><stats><crosses>1</crosses></sta...
# 3036  <cross><value><stats><crosses>1</crosses></sta...
# 3037  <cross><value><stats><crosses>1</crosses></sta...
# 3038  <cross><value><stats><crosses>1</crosses></sta...
# 3039  <cross><value><stats><crosses>1</crosses></sta...
#
#                                                  corner  \
# 0     <corner><value><stats><corners>1</corners></st...
# 1     <corner><value><stats><corners>1</corners></st...
# 2     <corner><value><stats><corners>1</corners></st...
# 3     <corner><value><stats><corners>1</corners></st...
# 4     <corner><value><stats><corners>1</corners></st...
# ...                                                 ...
# 3035  <corner><value><stats><corners>1</corners></st...
# 3036  <corner><value><stats><corners>1</corners></st...
# 3037  <corner><value><stats><corners>1</corners></st...
# 3038  <corner><value><stats><corners>1</corners></st...
# 3039  <corner><value><stats><corners>1</corners></st...
#
#                                              possession B365H B365D  B365A
# 0     <possession><value><comment>56</comment><event...  1.29   5.5  11.00
# 1     <possession><value><comment>65</comment><event...  1.20   6.5  15.00
# 2     <possession><value><comment>45</comment><event...  5.50   3.6   1.67
# 3     <possession><value><comment>50</comment><event...  1.91   3.4   4.20
# 4     <possession><value><comment>51</comment><event...  1.91   3.4   4.33
# ...                                                 ...   ...   ...    ...
# 3035  <possession><value><comment>54</comment><stats...  1.75   4.0   5.00
# 3036  <possession><value><comment>53</comment><stats...  2.05   3.4   4.20
# 3037  <possession><value><comment>45</comment><stats...  2.50   3.5   3.00
# 3038  <possession><value><comment>39</comment><stats...  6.00   4.2   1.62
# 3039  <possession><value><comment>50</comment><stats...  2.05   3.4   4.20
#
# [3040 rows x 22 columns]

# %%
df_LaLiga
# Out:
#          id  country_id  league_id     season  stage                 date  \
# 3040  21518       21518      21518  2008/2009      1  2008-08-30 00:00:00
# 3041  21519       21518      21518  2008/2009      1  2008-08-31 00:00:00
# 3042  21520       21518      21518  2008/2009      1  2008-08-31 00:00:00
# 3043  21521       21518      21518  2008/2009      1  2008-08-31 00:00:00
# 3044  21522       21518      21518  2008/2009      1  2008-08-31 00:00:00
# ...     ...         ...        ...        ...    ...                  ...
# 6075  24553       21518      21518  2015/2016      9  2015-10-25 00:00:00
# 6076  24554       21518      21518  2015/2016      9  2015-10-24 00:00:00
# 6077  24555       21518      21518  2015/2016      9  2015-10-26 00:00:00
# 6078  24556       21518      21518  2015/2016      9  2015-10-24 00:00:00
# 6079  24557       21518      21518  2015/2016      9  2015-10-23 00:00:00
#
#       match_api_id           home_team_api_id           away_team_api_id  \
# 3040        530023                Valencia CF               RCD Mallorca
# 3041        530084                 CA Osasuna              Villarreal CF
# 3042        530085  RC Deportivo de La Coruña             Real Madrid CF
# 3043        530086                CD Numancia               FC Barcelona
# 3044        530087           Racing Santander                 Sevilla FC
# ...            ...                        ...                        ...
# 6075       2030167            Atlético Madrid                Valencia CF
# 6076       2030168                  Málaga CF  RC Deportivo de La Coruña
# 6077       2030169    Athletic Club de Bilbao     Real Sporting de Gijón
# 6078       2030170                 Granada CF        Real Betis Balompié
# 6079       2030171             Rayo Vallecano               RCD Espanyol
#
#       home_team_goal  ...                                             shoton  \
# 3040               3  ...  <shoton><value><stats><shoton>1</shoton></stat...
# 3041               1  ...                                         <shoton />
# 3042               2  ...  <shoton><value><stats><blocked>1</blocked></st...
# 3043               1  ...  <shoton><value><stats><shoton>1</shoton></stat...
# 3044               1  ...                                         <shoton />
# ...              ...  ...                                                ...
# 6075               2  ...  <shoton><value><stats><shoton>1</shoton></stat...
# 6076               2  ...  <shoton><value><event_incident_typefk>876</eve...
# 6077               3  ...  <shoton><value><stats><blocked>1</blocked></st...
# 6078               1  ...  <shoton><value><stats><shoton>1</shoton></stat...
# 6079               3  ...  <shoton><value><stats><blocked>1</blocked></st...
#
#                                                 shotoff  \
# 3040  <shotoff><value><stats><shotoff>1</shotoff></s...
# 3041                                        <shotoff />
# 3042  <shotoff><value><stats><shotoff>1</shotoff></s...
# 3043  <shotoff><value><stats><shotoff>1</shotoff></s...
# 3044                                        <shotoff />
# ...                                                 ...
# 6075  <shotoff><value><stats><shotoff>1</shotoff></s...
# 6076  <shotoff><value><stats><shotoff>1</shotoff></s...
# 6077  <shotoff><value><stats><shotoff>1</shotoff></s...
# 6078  <shotoff><value><stats><shotoff>1</shotoff></s...
# 6079  <shotoff><value><stats><shotoff>1</shotoff></s...
#
#                                              foulcommit  \
# 3040  <foulcommit><value><stats><foulscommitted>1</f...
# 3041                                     <foulcommit />
# 3042  <foulcommit><value><stats><foulscommitted>1</f...
# 3043  <foulcommit><value><stats><foulscommitted>1</f...
# 3044                                     <foulcommit />
# ...                                                 ...
# 6075  <foulcommit><value><stats><foulscommitted>1</f...
# 6076  <foulcommit><value><stats><foulscommitted>1</f...
# 6077  <foulcommit><value><stats><foulscommitted>1</f...
# 6078  <foulcommit><value><stats><foulscommitted>1</f...
# 6079  <foulcommit><value><stats><foulscommitted>1</f...
#
#                                                    card  \
# 3040  <card><value><comment>y</comment><stats><ycard...
# 3041  <card><value><comment>y</comment><stats><ycard...
# 3042  <card><value><comment>y</comment><stats><ycard...
# 3043  <card><value><comment>y</comment><stats><ycard...
# 3044  <card><value><comment>y</comment><stats><ycard...
# ...                                                 ...
# 6075  <card><value><comment>y</comment><stats><ycard...
# 6076  <card><value><comment>y</comment><stats><ycard...
# 6077  <card><value><comment>y</comment><stats><ycard...
# 6078  <card><value><comment>y</comment><stats><ycard...
# 6079  <card><value><comment>y</comment><stats><ycard...
#
#                                                   cross  \
# 3040  <cross><value><stats><corners>1</corners></sta...
# 3041                                          <cross />
# 3042  <cross><value><stats><crosses>1</crosses></sta...
# 3043  <cross><value><stats><crosses>1</crosses></sta...
# 3044                                          <cross />
# ...                                                 ...
# 6075  <cross><value><stats><crosses>1</crosses></sta...
# 6076  <cross><value><stats><crosses>1</crosses></sta...
# 6077  <cross><value><stats><crosses>1</crosses></sta...
# 6078  <cross><value><stats><crosses>1</crosses></sta...
# 6079  <cross><value><stats><crosses>1</crosses></sta...
#
#                                                  corner  \
# 3040  <corner><value><stats><corners>1</corners></st...
# 3041                                         <corner />
# 3042  <corner><value><stats><corners>1</corners></st...
# 3043  <corner><value><stats><corners>1</corners></st...
# 3044                                         <corner />
# ...                                                 ...
# 6075  <corner><value><stats><corners>1</corners></st...
# 6076  <corner><value><stats><corners>1</corners></st...
# 6077  <corner><value><stats><corners>1</corners></st...
# 6078  <corner><value><stats><corners>1</corners></st...
# 6079  <corner><value><stats><corners>1</corners></st...
#
#                                              possession B365H B365D  B365A
# 3040  <possession><value><comment>53</comment><event...  1.70  3.60   5.25
# 3041                                     <possession />  2.80  3.30   2.50
# 3042  <possession><value><comment>44</comment><event...  3.50  3.30   2.10
# 3043  <possession><value><comment>27</comment><event...  7.00  4.00   1.50
# 3044                                     <possession />  2.80  3.30   2.50
# ...                                                 ...   ...   ...    ...
# 6075  <possession><value><comment>49</comment><stats...  1.57  3.80   6.50
# 6076  <possession><value><comment>53</comment><stats...  2.25  3.25   3.40
# 6077  <possession><value><comment>49</comment><stats...  1.53  4.00   7.00
# 6078  <possession><value><comment>50</comment><stats...  2.30  3.25   3.25
# 6079  <possession><value><comment>59</comment><stats...  2.20  3.40   3.20
#
# [3040 rows x 22 columns]

# %%
df_EPL.to_csv(path + "EPL.csv")
df_LaLiga.to_csv(path + "LaLiga.csv")

# %%
df_epl_stat = pd.read_csv('epl_stats.csv')
